# %%
#Reading an image
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread,imshow
#loading the image
image1=imread("img1.jfif")
imshow(image1)

# %%
#log transaformation of an image
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read an image
image = cv2.imread('img1.jfif')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Apply log transformation method
c = 255 / np.log(1 + np.max(image_rgb))
log_image = c * (np.log(image + 1))

# Specify the data type so that
# float value will be converted to int
log_image = np.array(log_image, dtype = np.uint8)

# Display both images
plt.imshow(image_rgb)
plt.show()
plt.imshow(log_image)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_7424/4076550568.py:12: RuntimeWarning: divide by zero encountered in log
#   log_image = c * (np.log(image + 1))

# %%
#negative transformation of an image
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('img1.jfif')
img_1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
colored_negative = abs(255-img)
title = ['negative ', 'coloured-negative']
plt.imshow(img_1)
plt.show()
plt.title(title[0])
plt.imshow(imgs[0])
plt.show()

# %%
#Negative transformation of an image
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('img10.jfif')
img_1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
neg = 255-img_1
plt.imshow(img_1)
plt.show()
plt.imshow(neg)
plt.show()

# %%
#mathematical operations on the image
#adding,subtracting,multiplying,dividing two images
import cv2
import matplotlib.pyplot as plt
img1=cv2.imread('star-1-300x168.jpg')
img2=cv2.imread('dot-300x168.jpg')
add=img1+img2
sub=img2-img1
mul=img1*img2
div=img2/img1
plt.imshow(add)
plt.show()
plt.imshow(sub)
plt.show()
plt.imshow(mul)
plt.show()
plt.imshow(div)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_7424/1349915946.py:10: RuntimeWarning: invalid value encountered in true_divide
#   div=img2/img1
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from skimage.io import imshow,imread
import matplotlib.pyplot as plt
img1=imread('lion.jpg')
imshow(img1)
fig,ax=plt.subplots(1,3,figsize=(6,4),sharey=True)
ax[0].imshow(img1[0:250,0:250])
ax[0].set_title('first block')
ax[1].imshow(img1[:,400:600])
ax[1].set_title('second block')
ax[2].imshow(img1[750:1000,1000:1500])
ax[2].set_title('third block')
# Out:
# Text(0.5, 1.0, 'third block')
