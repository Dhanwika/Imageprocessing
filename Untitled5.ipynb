# %%
#ORIGINAL IMAGE
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('img10.jfif', 1)
plt.imshow(img)

# %%
#IMAGE TRANSLATION
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('img10.jfif', 2)
rows, cols = img.shape
M = np.float32([[1, 0, 100], [0, 1, 50]])
dst = cv.warpAffine(img, M, (cols, rows))
cv.imshow('img', dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
#IMAGE CROPPING
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('img10.jfif', 1)
cropped_img = img[100:300, 100:300]
cv.imwrite('cropped_out.jpg', cropped_img)
plt.imshow(cropped_img)

# %%
#ORIGINAL IMAGE
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('img5.jpg', 1)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
#CROPPED IMAGE
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('img5.jpg', 1)
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cropped_img = img[500:2000, 500:2000]
cv.imwrite('cropped_out.jpg', cropped_img)
plt.imshow(cropped_img)

# %%
#image rotation
import numpy as np
import cv2 as cv
img = cv.imread('img10.jfif', 2)
rows, cols = img.shape
M = np.float32([[1, 0, 0], [0, -1, rows], [0, 0, 1]])
img_rotation = cv.warpAffine(img,cv.getRotationMatrix2D((cols/2, rows/2),30, 0.6),(cols, rows))
cv.imshow('img', img_rotation)
cv.imwrite('rotation_out.jpg', img_rotation)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
#IMAGE rotation
from PIL import Image
Original_Image = Image.open("img5.jpg")
rotated_image1 = Original_Image.rotate(180)
rotated_image2 = Original_Image.rotate(90)
rotated_image3 = Original_Image.rotate(60)
rotated_image4 = Original_Image.rotate(270)
rotated_image5 = Original_Image.rotate(45)
rotated_image1.show()
rotated_image2.show()
rotated_image3.show()
rotated_image4.show()
rotated_image5.show()

# %%
#IMAGE SCALING
import numpy as np
import cv2 as cv
img = cv.imread('img5.jpg', 2)
rows, cols = img.shape
img_shrinked = cv.resize(img, (200, 200),interpolation=cv.INTER_AREA)
#cv.imshow('img', img_shrinked)
img_enlarged = cv.resize(img_shrinked, None,fx=2.5, fy=2.5,interpolation=cv.INTER_CUBIC)
cv.imshow('img', img_enlarged)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
#IMAGE SCALING
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('img5.jpg', 0)
img_shrinked = cv.resize(img, (80, 200))
plt.imshow(img_shrinked)

# %%
#IMAGE SCALING
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('img5.jpg', 2)
img_enlarged = cv.resize(img, None,fx=5, fy=5,interpolation=cv.INTER_CUBIC)
plt.imshow(img_enlarged)

# %%
#IMAGE SCALING
import numpy as np
import cv2 as cv
img = cv.imread('img5.jpg', 2)
rows, cols = img.shape
img_shrinked = cv.resize(img, (60, 60),interpolation=cv.INTER_AREA)
cv.imshow('img', img_shrinked)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
#IMAGE SCALING
import numpy as np
import cv2 as cv
img = cv.imread('img5.jpg', 2)
rows, cols = img.shape
img_shrinked = cv.resize(img, (200, 200),interpolation=cv.INTER_AREA)
img_enlarged = cv.resize(img_shrinked, None,fx=5, fy=2.5,interpolation=cv.INTER_CUBIC)
cv.imshow('img', img_enlarged)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
#image shearing x axis
import numpy as np
import cv2 as cv
img = cv.imread('img10.jfif', 2)
rows, cols = img.shape
M = np.float32([[1, 0.5, 0], [0, 1, 0], [0, 0, 1]])
sheared_img = cv.warpPerspective(img, M, (int(cols*1.5), int(rows*1.5)))
cv.imshow('img', sheared_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('img10.jfif', 2)
rows, cols = img.shape
M = np.float32([[1, 0.5, 0], [0, 1, 0], [0, 0, 1]])
sheared_img = cv.warpPerspective(img, M, (int(cols*1.5), int(rows*1.5)))
plt.imshow(sheared_img)

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('img5.jpg', 2)
rows, cols = img.shape
M = np.float32([[1, 0, 0], [0.5, 1, 0], [0, 0, 1]])
sheared_img = cv.warpPerspective(img, M, (int(cols*1.5), int(rows*1.5)))
plt.imshow(sheared_img)

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('img5.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig, ax = plt.subplots(1, figsize=(12,8))
ax.axis('off')
plt.imshow(img[500:1000, 250:500])

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('img5.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imshow("image before upsampling",img)
img=cv2.pyrUp(img)
cv2.imshow("up sampling",img)
plt.imshow(img)
